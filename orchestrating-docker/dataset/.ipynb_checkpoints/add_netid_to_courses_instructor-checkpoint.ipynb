# %%
import pandas as pd
import csv
print ('Modules Loaded')
# Out:
# Modules Loaded

# %%
df = pd.read_csv("ece_cs_courses.csv")
df
# Out:
#       Course                 Instructor     Term  \
# 0    ECE-408            Patel, Sanjay J  2018-fa
# 1    ECE-401    Hasegawa-Johnso, Mark A  2017-sp
# 2    ECE-403           Smaragdis, Paris  2014-sp
# 3    ECE-402             Haken, Lippold  2018-fa
# 4    ECE-481           Lyding, Joseph W  2018-sp
# 5    ECE-480             Liang, Zhi-Pei  2018-fa
# 6    ECE-483      Hanumolu, Pavan Kumar  2018-sp
# 7    ECE-482         Shanbhag, Naresh R  2018-fa
# 8    ECE-485                Liu, Gang L  2017-fa
# 9    ECE-486            Raginsky, Maxim  2018-fa
# 10   ECE-488         Dallesasse, John M  2018-fa
# 11   ECE-333              Gross, George  2018-fa
# 12   ECE-120     Kindratenko, Volodymyr  2018-fa
# 13   ECE-330          Schuh, Jonathon K  2018-fa
# 14   ECE-458              Kudeki, Erhan  2010-sp
# 15   ECE-510                Jain, Kanti  2013-fa
# 16   ECE-535      Leburton, Jean-Pierre  2016-fa
# 17   ECE-534         Milenkovic, Olgica  2018-fa
# 18   ECE-536             Chuang, Shun L  2011-sp
# 19   ECE-532          Choquette, Kent D  2013-fa
# 20   ECE-554  Dominguez-Garci, Alejandr  2015-sp
# 21   ECE-553         Liberzon, Daniel M  2013-sp
# 22   ECE-551             Dokmanic, Ivan  2018-fa
# 23   ECE-550         Hutchinson, Seth A  2016-sp
# 24   ECE-442           Rosenbaum, Elyse  2011-sp
# 25   ECE-329              Waldrop, Lara  2018-fa
# 26   ECE-498        Levchenko, Kirill I  2018-fa
# 27   ECE-490                    Hu, Bin  2018-fa
# 28   ECE-518                Li, Xiuling  2017-fa
# 29   ECE-528        Stipanovic, Dusan M  2017-sp
# ..       ...                        ...      ...
# 87   ECE-350              Gong, Songbin  2018-sp
# 88   ECE-420        Levinson, Stephen E  2018-sp
# 89   ECE-101       Schmitz, Christopher  2013-sp
# 90   ECE-580        Srikant, Rayadurgam  2013-fa
# 91   ECE-581      Hanumolu, Pavan Kumar  2018-fa
# 92   ECE-210              Alvarez, Juan  2018-fa
# 93   ECE-586        Srikant, Rayadurgam  2017-fa
# 94   ECE-290             Brown, Donna J  2014-sp
# 95   ECE-298                Allen, Jont  2017-fa
# 96   ECE-511              Kim, Nam Sung  2016-fa
# 97   ECE-459              Alvarez, Juan  2016-fa
# 98   ECE-517         Liberzon, Daniel M  2018-fa
# 99   ECE-515         Baryshnikov, Yuliy  2018-fa
# 100  ECE-452               Chew, Weng C  2014-fa
# 101  ECE-453           Franke, Steven J  2018-sp
# 102  ECE-450              Kudeki, Erhan  2011-sp
# 103  ECE-451        Schutt-Aine, Jose E  2017-sp
# 104  ECE-456               Gao, Xingxin  2016-fa
# 105  ECE-457              Gong, Songbin  2017-sp
# 106  ECE-454              Kudeki, Erhan  2018-sp
# 107  ECE-455              Eden, James G  2018-fa
# 108  ECE-439       Roy Choudhury, Romit  2017-fa
# 109  ECE-342                  Zhou, Jin  2018-fa
# 110  ECE-343  Radhakrishnan, Chandrasek  2018-sp
# 111  ECE-340         Dallesasse, John M  2018-fa
# 112  ECE-437              Gruev, Viktor  2018-fa
# 113  ECE-430               Bazzi, Ali M  2011-sp
# 114  ECE-431            Haran, Kiruba S  2018-sp
# 115  ECE-220             Chen, Yuting W  2018-fa
# 116  ECE-508             Hwu, Wen-Mei W  2017-sp
#
#                               Title
# 0      Applied Parallel Programming
# 1         Signal and Image Analysis
# 2                 Audio Engineering
# 3        Electronic Music Synthesis
# 4                    Nanotechnology
# 5        Magnetic Resonance Imaging
# 6                  Analog IC Design
# 7                 Digital IC Design
# 8            MEMS Devices & Systems
# 9                   Control Systems
# 10      Compound Semicond & Devices
# 11            Green Electric Energy
# 12        Introduction to Computing
# 13    Power Ckts & Electromechanics
# 14      Applic of Radio Wave Propag
# 15        Micro and Nanolithography
# 16     Theory of Semicond & Devices
# 17                 Random Processes
# 18   Integ Optics & Optoelectronics
# 19   Compnd Semicond & Diode Lasers
# 20       Dynamic System Reliability
# 21          Optimum Control Systems
# 22     Digital Signal Processing II
# 23        Advanced Robotic Planning
# 24              Electronic Circuits
# 25               Fields and Waves I
# 26     eCrime & Internet Serv Abuse
# 27     Introduction to Optimization
# 28       Adv Semiconductor Nanotech
# 29    Analysis of Nonlinear Systems
# ..                              ...
# 87              Fields and Waves II
# 88          Embedded DSP Laboratory
# 89   Exploring Digital Info Technol
# 90   Optimiz by Vector Space Methds
# 91        Advanced Analog IC Design
# 92         Analog Signal Processing
# 93     MDPs, Reinforcement Learning
# 94           Computer Engineering I
# 95     Concepts in Engineering Math
# 96            Computer Architecture
# 97           Communications Systems
# 98     Nonlinear & Adaptive Control
# 99   Control System Theory & Design
# 100          Electromagnetic Fields
# 101  Wireless Communication Systems
# 102        Lines, Fields, and Waves
# 103      Adv Microwave Measurements
# 104    Global Nav Satellite Systems
# 105    Microwave Devices & Circuits
# 106                        Antennas
# 107             Optical Electronics
# 108               Wireless Networks
# 109             Electronic Circuits
# 110  Electronic Circuits Laboratory
# 111       Semiconductor Electronics
# 112     Sensors and Instrumentation
# 113   Power Ckts & Electromechanics
# 114              Electric Machinery
# 115  Computer Systems & Programming
# 116    Manycore Parallel Algorithms
#
# [117 rows x 4 columns]

# %%
count = df["Course"].count()
hash_map = {}

for i in range(count):
    value = df["Instructor"][i]
    key = df["Course"][i]
    term = df["Term"][i]
    title = df["Title"][i]
    if key not in hash_map:
        hash_map[key] = [key, value, term, title]
hash_map
# Out:
# {'ECE-101': ['ECE-101',
#   'Schmitz, Christopher',
#   '2013-sp',
#   'Exploring Digital Info Technol'],
#  'ECE-110': ['ECE-110',
#   'Schmitz, Christopher',
#   '2018-fa',
#   'Introduction to Electronics'],
#  'ECE-120': ['ECE-120',
#   'Kindratenko, Volodymyr',
#   '2018-fa',
#   'Introduction to Computing'],
#  'ECE-190': ['ECE-190',
#   'Hu, Yih-Chun',
#   '2013-fa',
#   'Intro to Computing Systems'],
#  'ECE-198': ['ECE-198',
#   'Kindratenko, Volodymyr',
#   '2014-fa',
#   'Introduction to Computer Eng'],
#  'ECE-199': ['ECE-199',
#   'Varodayan, David',
#   '2018-fa',
#   'Undergraduate Open Seminar'],
#  'ECE-205': ['ECE-205',
#   'Radhakrishnan, Chandrasek',
#   '2018-fa',
#   'Electrical & Electronic Ckts'],
#  'ECE-206': ['ECE-206',
#   'Radhakrishnan, Chandrasek',
#   '2018-fa',
#   'Electrical & Electronics Lab'],
#  'ECE-210': ['ECE-210',
#   'Alvarez, Juan',
#   '2018-fa',
#   'Analog Signal Processing'],
#  'ECE-220': ['ECE-220',
#   'Chen, Yuting W',
#   '2018-fa',
#   'Computer Systems & Programming'],
#  'ECE-290': ['ECE-290', 'Brown, Donna J', '2014-sp', 'Computer Engineering I'],
#  'ECE-298': ['ECE-298',
#   'Allen, Jont',
#   '2017-fa',
#   'Concepts in Engineering Math'],
#  'ECE-304': ['ECE-304', 'Choquette, Kent D', '2018-fa', 'Photonic Devices'],
#  'ECE-307': ['ECE-307',
#   'Gross, George',
#   '2016-sp',
#   'Techniques for Engrg Decisions'],
#  'ECE-310': ['ECE-310',
#   'Shomorony, Ilan',
#   '2018-fa',
#   'Digital Signal Processing'],
#  'ECE-311': ['ECE-311',
#   'Bresler, Yoram',
#   '2018-fa',
#   'Digital Signal Processing Lab'],
#  'ECE-313': ['ECE-313',
#   'Veeravalli, Venugopal V',
#   '2018-fa',
#   'Probability with Engrg Applic'],
#  'ECE-314': ['ECE-314',
#   'Hajek, Bruce',
#   '2018-fa',
#   'Probability in Engineering Lab'],
#  'ECE-316': ['ECE-316',
#   'Hillmer, Philip M',
#   '2018-fa',
#   'Ethics and Engineering'],
#  'ECE-317': ['ECE-317', 'He, Wei', '2018-sp', 'ECE Technology & Management'],
#  'ECE-329': ['ECE-329', 'Waldrop, Lara', '2018-fa', 'Fields and Waves I'],
#  'ECE-330': ['ECE-330',
#   'Schuh, Jonathon K',
#   '2018-fa',
#   'Power Ckts & Electromechanics'],
#  'ECE-333': ['ECE-333', 'Gross, George', '2018-fa', 'Green Electric Energy'],
#  'ECE-340': ['ECE-340',
#   'Dallesasse, John M',
#   '2018-fa',
#   'Semiconductor Electronics'],
#  'ECE-342': ['ECE-342', 'Zhou, Jin', '2018-fa', 'Electronic Circuits'],
#  'ECE-343': ['ECE-343',
#   'Radhakrishnan, Chandrasek',
#   '2018-sp',
#   'Electronic Circuits Laboratory'],
#  'ECE-350': ['ECE-350', 'Gong, Songbin', '2018-sp', 'Fields and Waves II'],
#  'ECE-361': ['ECE-361', 'Alvarez, Juan', '2017-sp', 'Digital Communications'],
#  'ECE-380': ['ECE-380', 'Boppart, Stephen A', '2018-fa', 'Biomedical Imaging'],
#  'ECE-385': ['ECE-385',
#   'Cheng, Zuofu',
#   '2018-fa',
#   'Digital Systems Laboratory'],
#  'ECE-391': ['ECE-391',
#   'Kalbarczyk, Zbigniew T',
#   '2018-fa',
#   'Computer Systems Engineering'],
#  'ECE-395': ['ECE-395',
#   'Haken, Lippold',
#   '2017-sp',
#   'Advanced Digital Projects Lab'],
#  'ECE-398': ['ECE-398', 'Do, Minh N', '2018-fa', 'Making Sense of Big Data'],
#  'ECE-401': ['ECE-401',
#   'Hasegawa-Johnso, Mark A',
#   '2017-sp',
#   'Signal and Image Analysis'],
#  'ECE-402': ['ECE-402',
#   'Haken, Lippold',
#   '2018-fa',
#   'Electronic Music Synthesis'],
#  'ECE-403': ['ECE-403', 'Smaragdis, Paris', '2014-sp', 'Audio Engineering'],
#  'ECE-408': ['ECE-408',
#   'Patel, Sanjay J',
#   '2018-fa',
#   'Applied Parallel Programming'],
#  'ECE-410': ['ECE-410',
#   'Singer, Andrew C',
#   '2011-sp',
#   'Digital Signal Processing I'],
#  'ECE-411': ['ECE-411',
#   'Kumar, Rakesh',
#   '2018-fa',
#   'Computer Organization & Design'],
#  'ECE-416': ['ECE-416', 'Cunningham, Brian T', '2018-sp', 'Biosensors'],
#  'ECE-417': ['ECE-417',
#   'Hasegawa-Johnso, Mark A',
#   '2018-fa',
#   'Multimedia Signal Processing'],
#  'ECE-418': ['ECE-418',
#   'Moulin, Pierre',
#   '2017-sp',
#   'Image & Video Processing'],
#  'ECE-420': ['ECE-420',
#   'Levinson, Stephen E',
#   '2018-sp',
#   'Embedded DSP Laboratory'],
#  'ECE-425': ['ECE-425',
#   'Kindratenko, Volodymyr',
#   '2017-fa',
#   'Intro to VLSI System Design'],
#  'ECE-430': ['ECE-430',
#   'Bazzi, Ali M',
#   '2011-sp',
#   'Power Ckts & Electromechanics'],
#  'ECE-431': ['ECE-431', 'Haran, Kiruba S', '2018-sp', 'Electric Machinery'],
#  'ECE-435': ['ECE-435',
#   'Caesar, Matthew C',
#   '2018-fa',
#   'Computer Networking Laboratory'],
#  'ECE-437': ['ECE-437',
#   'Gruev, Viktor',
#   '2018-fa',
#   'Sensors and Instrumentation'],
#  'ECE-439': ['ECE-439',
#   'Roy Choudhury, Romit',
#   '2017-fa',
#   'Wireless Networks'],
#  'ECE-440': ['ECE-440',
#   'Liu, Gang L',
#   '2011-sp',
#   'Solid State Electronic Devices'],
#  'ECE-441': ['ECE-441',
#   'Zhu, Wenjuan',
#   '2018-sp',
#   'Physcs & Modeling Semicond Dev'],
#  'ECE-442': ['ECE-442', 'Rosenbaum, Elyse', '2011-sp', 'Electronic Circuits'],
#  'ECE-443': ['ECE-443',
#   'Zhang, Jianhua',
#   '2010-fa',
#   'Electronic Circuits Laboratory'],
#  'ECE-444': ['ECE-444',
#   'Li, Xiuling',
#   '2018-fa',
#   'IC Device Theory & Fabrication'],
#  'ECE-445': ['ECE-445',
#   'Fliflet, Arne W',
#   '2018-fa',
#   'Senior Design Project Lab'],
#  'ECE-447': ['ECE-447',
#   'Gong, Songbin',
#   '2016-fa',
#   'Active Microwave Ckt Design'],
#  'ECE-450': ['ECE-450',
#   'Kudeki, Erhan',
#   '2011-sp',
#   'Lines, Fields, and Waves'],
#  'ECE-451': ['ECE-451',
#   'Schutt-Aine, Jose E',
#   '2017-sp',
#   'Adv Microwave Measurements'],
#  'ECE-452': ['ECE-452', 'Chew, Weng C', '2014-fa', 'Electromagnetic Fields'],
#  'ECE-453': ['ECE-453',
#   'Franke, Steven J',
#   '2018-sp',
#   'Wireless Communication Systems'],
#  'ECE-454': ['ECE-454', 'Kudeki, Erhan', '2018-sp', 'Antennas'],
#  'ECE-455': ['ECE-455', 'Eden, James G', '2018-fa', 'Optical Electronics'],
#  'ECE-456': ['ECE-456',
#   'Gao, Xingxin',
#   '2016-fa',
#   'Global Nav Satellite Systems'],
#  'ECE-457': ['ECE-457',
#   'Gong, Songbin',
#   '2017-sp',
#   'Microwave Devices & Circuits'],
#  'ECE-458': ['ECE-458',
#   'Kudeki, Erhan',
#   '2010-sp',
#   'Applic of Radio Wave Propag'],
#  'ECE-459': ['ECE-459', 'Alvarez, Juan', '2016-fa', 'Communications Systems'],
#  'ECE-461': ['ECE-461',
#   'Viswanath, Pramod',
#   '2018-sp',
#   'Digital Communications'],
#  'ECE-462': ['ECE-462', 'Chen, Deming', '2018-sp', 'Logic Synthesis'],
#  'ECE-464': ['ECE-464', 'Banerjee, Arijit', '2018-fa', 'Power Electronics'],
#  'ECE-468': ['ECE-468', 'Waldrop, Lara', '2018-sp', 'Optical Remote Sensing'],
#  'ECE-469': ['ECE-469',
#   'Banerjee, Arijit',
#   '2018-fa',
#   'Power Electronics Laboratory'],
#  'ECE-470': ['ECE-470',
#   'Belabbas, Mohamed Ali',
#   '2018-fa',
#   'Introduction to Robotics'],
#  'ECE-473': ['ECE-473',
#   'Oelze, Michael L',
#   '2017-fa',
#   'Fund of Engrg Acoustics'],
#  'ECE-476': ['ECE-476',
#   'Dominguez-Garci, Alejandr',
#   '2018-fa',
#   'Power System Analysis'],
#  'ECE-480': ['ECE-480',
#   'Liang, Zhi-Pei',
#   '2018-fa',
#   'Magnetic Resonance Imaging'],
#  'ECE-481': ['ECE-481', 'Lyding, Joseph W', '2018-sp', 'Nanotechnology'],
#  'ECE-482': ['ECE-482', 'Shanbhag, Naresh R', '2018-fa', 'Digital IC Design'],
#  'ECE-483': ['ECE-483',
#   'Hanumolu, Pavan Kumar',
#   '2018-sp',
#   'Analog IC Design'],
#  'ECE-485': ['ECE-485', 'Liu, Gang L', '2017-fa', 'MEMS Devices & Systems'],
#  'ECE-486': ['ECE-486', 'Raginsky, Maxim', '2018-fa', 'Control Systems'],
#  'ECE-488': ['ECE-488',
#   'Dallesasse, John M',
#   '2018-fa',
#   'Compound Semicond & Devices'],
#  'ECE-490': ['ECE-490', 'Hu, Bin', '2018-fa', 'Introduction to Optimization'],
#  'ECE-498': ['ECE-498',
#   'Levchenko, Kirill I',
#   '2018-fa',
#   'eCrime & Internet Serv Abuse'],
#  'ECE-508': ['ECE-508',
#   'Hwu, Wen-Mei W',
#   '2017-sp',
#   'Manycore Parallel Algorithms'],
#  'ECE-510': ['ECE-510', 'Jain, Kanti', '2013-fa', 'Micro and Nanolithography'],
#  'ECE-511': ['ECE-511', 'Kim, Nam Sung', '2016-fa', 'Computer Architecture'],
#  'ECE-515': ['ECE-515',
#   'Baryshnikov, Yuliy',
#   '2018-fa',
#   'Control System Theory & Design'],
#  'ECE-517': ['ECE-517',
#   'Liberzon, Daniel M',
#   '2018-fa',
#   'Nonlinear & Adaptive Control'],
#  'ECE-518': ['ECE-518',
#   'Li, Xiuling',
#   '2017-fa',
#   'Adv Semiconductor Nanotech'],
#  'ECE-520': ['ECE-520',
#   'Jin, Jianming',
#   '2018-fa',
#   'EM Waves & Radiating Systems'],
#  'ECE-526': ['ECE-526',
#   'Vaidya, Nitin H',
#   '2016-fa',
#   'Distributed Algorithms'],
#  'ECE-527': ['ECE-527', 'Chen, Deming', '2018-fa', 'System-On-Chip Design'],
#  'ECE-528': ['ECE-528',
#   'Stipanovic, Dusan M',
#   '2017-sp',
#   'Analysis of Nonlinear Systems'],
#  'ECE-532': ['ECE-532',
#   'Choquette, Kent D',
#   '2013-fa',
#   'Compnd Semicond & Diode Lasers'],
#  'ECE-534': ['ECE-534', 'Milenkovic, Olgica', '2018-fa', 'Random Processes'],
#  'ECE-535': ['ECE-535',
#   'Leburton, Jean-Pierre',
#   '2016-fa',
#   'Theory of Semicond & Devices'],
#  'ECE-536': ['ECE-536',
#   'Chuang, Shun L',
#   '2011-sp',
#   'Integ Optics & Optoelectronics'],
#  'ECE-541': ['ECE-541',
#   'Noureddine, Mohammad',
#   '2018-fa',
#   'Computer Systems Analysis'],
#  'ECE-543': ['ECE-543',
#   'Raginsky, Maxim',
#   '2018-sp',
#   'Statistical Learning Theory'],
#  'ECE-544': ['ECE-544',
#   'Schwing, Alexander G',
#   '2018-fa',
#   'Pattern Recognition'],
#  'ECE-546': ['ECE-546',
#   'Schutt-Aine, Jose E',
#   '2018-sp',
#   'Advanced Signal Integrity'],
#  'ECE-547': ['ECE-547',
#   'Schwing, Alexander G',
#   '2017-sp',
#   'Topics in Image Processing'],
#  'ECE-549': ['ECE-549', 'Lazebnik, Svetlana', '2018-sp', 'Computer Vision'],
#  'ECE-550': ['ECE-550',
#   'Hutchinson, Seth A',
#   '2016-sp',
#   'Advanced Robotic Planning'],
#  'ECE-551': ['ECE-551',
#   'Dokmanic, Ivan',
#   '2018-fa',
#   'Digital Signal Processing II'],
#  'ECE-553': ['ECE-553',
#   'Liberzon, Daniel M',
#   '2013-sp',
#   'Optimum Control Systems'],
#  'ECE-554': ['ECE-554',
#   'Dominguez-Garci, Alejandr',
#   '2015-sp',
#   'Dynamic System Reliability'],
#  'ECE-561': ['ECE-561',
#   'Veeravalli, Venugopal V',
#   '2014-sp',
#   'Detection & Estimation Theory'],
#  'ECE-563': ['ECE-563', 'Varshney, Lav R', '2018-fa', 'Information Theory'],
#  'ECE-564': ['ECE-564',
#   'Popescu, Gabriel',
#   '2015-sp',
#   'Modern Light Microscopy'],
#  'ECE-566': ['ECE-566',
#   'Moulin, Pierre',
#   '2018-fa',
#   'Computational Inference'],
#  'ECE-569': ['ECE-569',
#   'Carney, Paul S',
#   '2014-fa',
#   'Inverse Problems in Optics'],
#  'ECE-576': ['ECE-576',
#   'Overbye, Thomas J',
#   '2014-sp',
#   'Power System Dynm & Stability'],
#  'ECE-580': ['ECE-580',
#   'Srikant, Rayadurgam',
#   '2013-fa',
#   'Optimiz by Vector Space Methds'],
#  'ECE-581': ['ECE-581',
#   'Hanumolu, Pavan Kumar',
#   '2018-fa',
#   'Advanced Analog IC Design'],
#  'ECE-586': ['ECE-586',
#   'Srikant, Rayadurgam',
#   '2017-fa',
#   'MDPs, Reinforcement Learning'],
#  'ECE-598': ['ECE-598',
#   'Zhu, Wenjuan',
#   '2018-fa',
#   '2D Material Electr & Photonics']}

# %%
with open('ece_cs_courses.csv', 'rb') as f:
    file_ = csv.reader(f)
    list_of_name = map(tuple, file_)
list_of_name.pop(0)
print(list_of_name)
# Out:
# [('ECE-408', 'Patel, Sanjay J', '2018-fa', 'Applied Parallel Programming'), ('ECE-401', 'Hasegawa-Johnso, Mark A', '2017-sp', 'Signal and Image Analysis'), ('ECE-403', 'Smaragdis, Paris', '2014-sp', 'Audio Engineering'), ('ECE-402', 'Haken, Lippold', '2018-fa', 'Electronic Music Synthesis'), ('ECE-481', 'Lyding, Joseph W', '2018-sp', 'Nanotechnology'), ('ECE-480', 'Liang, Zhi-Pei', '2018-fa', 'Magnetic Resonance Imaging'), ('ECE-483', 'Hanumolu, Pavan Kumar', '2018-sp', 'Analog IC Design'), ('ECE-482', 'Shanbhag, Naresh R', '2018-fa', 'Digital IC Design'), ('ECE-485', 'Liu, Gang L', '2017-fa', 'MEMS Devices & Systems'), ('ECE-486', 'Raginsky, Maxim', '2018-fa', 'Control Systems'), ('ECE-488', 'Dallesasse, John M', '2018-fa', 'Compound Semicond & Devices'), ('ECE-333', 'Gross, George', '2018-fa', 'Green Electric Energy'), ('ECE-120', 'Kindratenko, Volodymyr', '2018-fa', 'Introduction to Computing'), ('ECE-330', 'Schuh, Jonathon K', '2018-fa', 'Power Ckts & Electromechanics'), ('ECE-458', 'Kudeki, Erhan', '2010-sp', 'Applic of Radio Wave Propag'), ('ECE-510', 'Jain, Kanti', '2013-fa', 'Micro and Nanolithography'), ('ECE-535', 'Leburton, Jean-Pierre', '2016-fa', 'Theory of Semicond & Devices'), ('ECE-534', 'Milenkovic, Olgica', '2018-fa', 'Random Processes'), ('ECE-536', 'Chuang, Shun L', '2011-sp', 'Integ Optics & Optoelectronics'), ('ECE-532', 'Choquette, Kent D', '2013-fa', 'Compnd Semicond & Diode Lasers'), ('ECE-554', 'Dominguez-Garci, Alejandr', '2015-sp', 'Dynamic System Reliability'), ('ECE-553', 'Liberzon, Daniel M', '2013-sp', 'Optimum Control Systems'), ('ECE-551', 'Dokmanic, Ivan', '2018-fa', 'Digital Signal Processing II'), ('ECE-550', 'Hutchinson, Seth A', '2016-sp', 'Advanced Robotic Planning'), ('ECE-442', 'Rosenbaum, Elyse', '2011-sp', 'Electronic Circuits'), ('ECE-329', 'Waldrop, Lara', '2018-fa', 'Fields and Waves I'), ('ECE-498', 'Levchenko, Kirill I', '2018-fa', 'eCrime & Internet Serv Abuse'), ('ECE-490', 'Hu, Bin', '2018-fa', 'Introduction to Optimization'), ('ECE-518', 'Li, Xiuling', '2017-fa', 'Adv Semiconductor Nanotech'), ('ECE-528', 'Stipanovic, Dusan M', '2017-sp', 'Analysis of Nonlinear Systems'), ('ECE-520', 'Jin, Jianming', '2018-fa', 'EM Waves & Radiating Systems'), ('ECE-526', 'Vaidya, Nitin H', '2016-fa', 'Distributed Algorithms'), ('ECE-527', 'Chen, Deming', '2018-fa', 'System-On-Chip Design'), ('ECE-549', 'Lazebnik, Svetlana', '2018-sp', 'Computer Vision'), ('ECE-544', 'Schwing, Alexander G', '2018-fa', 'Pattern Recognition'), ('ECE-546', 'Schutt-Aine, Jose E', '2018-sp', 'Advanced Signal Integrity'), ('ECE-547', 'Schwing, Alexander G', '2017-sp', 'Topics in Image Processing'), ('ECE-541', 'Noureddine, Mohammad', '2018-fa', 'Computer Systems Analysis'), ('ECE-543', 'Raginsky, Maxim', '2018-sp', 'Statistical Learning Theory'), ('ECE-311', 'Bresler, Yoram', '2018-fa', 'Digital Signal Processing Lab'), ('ECE-310', 'Shomorony, Ilan', '2018-fa', 'Digital Signal Processing'), ('ECE-313', 'Veeravalli, Venugopal V', '2018-fa', 'Probability with Engrg Applic'), ('ECE-314', 'Hajek, Bruce', '2018-fa', 'Probability in Engineering Lab'), ('ECE-317', 'He, Wei', '2018-sp', 'ECE Technology & Management'), ('ECE-316', 'Hillmer, Philip M', '2018-fa', 'Ethics and Engineering'), ('ECE-391', 'Kalbarczyk, Zbigniew T', '2018-fa', 'Computer Systems Engineering'), ('ECE-435', 'Caesar, Matthew C', '2018-fa', 'Computer Networking Laboratory'), ('ECE-395', 'Haken, Lippold', '2017-sp', 'Advanced Digital Projects Lab'), ('ECE-398', 'Do, Minh N', '2018-fa', 'Making Sense of Big Data'), ('ECE-416', 'Cunningham, Brian T', '2018-sp', 'Biosensors'), ('ECE-417', 'Hasegawa-Johnso, Mark A', '2018-fa', 'Multimedia Signal Processing'), ('ECE-410', 'Singer, Andrew C', '2011-sp', 'Digital Signal Processing I'), ('ECE-411', 'Kumar, Rakesh', '2018-fa', 'Computer Organization & Design'), ('ECE-418', 'Moulin, Pierre', '2017-sp', 'Image & Video Processing'), ('ECE-307', 'Gross, George', '2016-sp', 'Techniques for Engrg Decisions'), ('ECE-3 ...

# %%
map_ = {}
for line in list_of_name:
    name = line[1].split(',')
    lastname = name[0]
    first_and_middle = name[1].split(' ')
    firstname = first_and_middle[1]
#     print(firstname)
#     print(lastname)
    class_ = line[0]
    term = line[2]
    title = line[3]
    class_term = class_ + term
#     print(class_term)
    map_[class_term] = [class_, firstname, lastname, term, title]
print(map_)
# Out:
# {'ECE-4032014-sp': ['ECE-403', 'Paris', 'Smaragdis', '2014-sp', 'Audio Engineering'], 'ECE-5802013-fa': ['ECE-580', 'Rayadurgam', 'Srikant', '2013-fa', 'Optimiz by Vector Space Methds'], 'ECE-4982018-fa': ['ECE-498', 'Kirill', 'Levchenko', '2018-fa', 'eCrime & Internet Serv Abuse'], 'ECE-3072016-sp': ['ECE-307', 'George', 'Gross', '2016-sp', 'Techniques for Engrg Decisions'], 'ECE-1982014-fa': ['ECE-198', 'Volodymyr', 'Kindratenko', '2014-fa', 'Introduction to Computer Eng'], 'ECE-5692014-fa': ['ECE-569', 'Paul', 'Carney', '2014-fa', 'Inverse Problems in Optics'], 'ECE-4392017-fa': ['ECE-439', 'Romit', 'Roy Choudhury', '2017-fa', 'Wireless Networks'], 'ECE-2052018-fa': ['ECE-205', 'Chandrasek', 'Radhakrishnan', '2018-fa', 'Electrical & Electronic Ckts'], 'ECE-4862018-fa': ['ECE-486', 'Maxim', 'Raginsky', '2018-fa', 'Control Systems'], 'ECE-4102011-sp': ['ECE-410', 'Andrew', 'Singer', '2011-sp', 'Digital Signal Processing I'], 'ECE-5812018-fa': ['ECE-581', 'Pavan', 'Hanumolu', '2018-fa', 'Advanced Analog IC Design'], 'ECE-3112018-fa': ['ECE-311', 'Yoram', 'Bresler', '2018-fa', 'Digital Signal Processing Lab'], 'ECE-3302018-fa': ['ECE-330', 'Jonathon', 'Schuh', '2018-fa', 'Power Ckts & Electromechanics'], 'ECE-4402011-sp': ['ECE-440', 'Gang', 'Liu', '2011-sp', 'Solid State Electronic Devices'], 'ECE-5512018-fa': ['ECE-551', 'Ivan', 'Dokmanic', '2018-fa', 'Digital Signal Processing II'], 'ECE-5492018-sp': ['ECE-549', 'Svetlana', 'Lazebnik', '2018-sp', 'Computer Vision'], 'ECE-3042018-fa': ['ECE-304', 'Kent', 'Choquette', '2018-fa', 'Photonic Devices'], 'ECE-5112016-fa': ['ECE-511', 'Nam', 'Kim', '2016-fa', 'Computer Architecture'], 'ECE-1012013-sp': ['ECE-101', 'Christopher', 'Schmitz', '2013-sp', 'Exploring Digital Info Technol'], 'ECE-5612014-sp': ['ECE-561', 'Venugopal', 'Veeravalli', '2014-sp', 'Detection & Estimation Theory'], 'ECE-4432010-fa': ['ECE-443', 'Jianhua', 'Zhang', '2010-fa', 'Electronic Circuits Laboratory'], 'ECE-3802018-fa': ['ECE-380', 'Stephen', 'Boppart', '2018-fa', 'Biomedical Imaging'], 'ECE-5542015-sp': ['ECE-554', 'Alejandr', 'Dominguez-Garci', '2015-sp', 'Dynamic System Reliability'], 'ECE-4412018-sp': ['ECE-441', 'Wenjuan', 'Zhu', '2018-sp', 'Physcs & Modeling Semicond Dev'], 'ECE-5412018-fa': ['ECE-541', 'Mohammad', 'Noureddine', '2018-fa', 'Computer Systems Analysis'], 'ECE-3332018-fa': ['ECE-333', 'George', 'Gross', '2018-fa', 'Green Electric Energy'], 'ECE-2062018-fa': ['ECE-206', 'Chandrasek', 'Radhakrishnan', '2018-fa', 'Electrical & Electronics Lab'], 'ECE-3502018-sp': ['ECE-350', 'Songbin', 'Gong', '2018-sp', 'Fields and Waves II'], 'ECE-4162018-sp': ['ECE-416', 'Brian', 'Cunningham', '2018-sp', 'Biosensors'], 'ECE-1902013-fa': ['ECE-190', 'Yih-Chun', 'Hu', '2013-fa', 'Intro to Computing Systems'], 'ECE-5282017-sp': ['ECE-528', 'Dusan', 'Stipanovic', '2017-sp', 'Analysis of Nonlinear Systems'], 'ECE-4572017-sp': ['ECE-457', 'Songbin', 'Gong', '2017-sp', 'Microwave Devices & Circuits'], 'ECE-4592016-fa': ['ECE-459', 'Juan', 'Alvarez', '2016-fa', 'Communications Systems'], 'ECE-5502016-sp': ['ECE-550', 'Seth', 'Hutchinson', '2016-sp', 'Advanced Robotic Planning'], 'ECE-4442018-fa': ['ECE-444', 'Xiuling', 'Li', '2018-fa', 'IC Device Theory & Fabrication'], 'ECE-5262016-fa': ['ECE-526', 'Nitin', 'Vaidya', '2016-fa', 'Distributed Algorithms'], 'ECE-4502011-sp': ['ECE-450', 'Erhan', 'Kudeki', '2011-sp', 'Lines, Fields, and Waves'], 'ECE-5472017-sp': ['ECE-547', 'Alexander', 'Schwing', '2017-sp', 'Topics in Image Processing'], 'ECE-5182017-fa': ['ECE-518', 'Xiuling', 'Li', '2017-fa', 'Adv Semiconductor Nanotech'], 'ECE-4832018-sp': ['ECE-483', 'Pavan', 'Hanumolu', '2018-sp', 'Analog IC Design'], 'ECE-4012017-sp': ['ECE-401', 'Mark', 'Hasegawa-Johnso', '2017-sp', 'Signal and Image Analysis'], 'ECE-3432018-sp': ['ECE-343', 'Chandrasek', 'Radhakrishnan', '2018-sp', 'Electronic Circuits Laboratory'], 'ECE-1202018-fa': ['ECE-120', 'Volodymyr', 'Kindratenko', '2018-fa', 'Introduction to Computing'], 'ECE-58 ...

# %%
df2 = pd.read_csv("ece_faculty_netid_added.csv")
df2
# Out:
#         Netid      FirstName          LastName                  Email
# 0     pmoulin         Pierre            Moulin   pmoulin@illinois.edu
# 1      niaohe           Niao                He    niaohe@illinois.edu
# 2      druzic          David             Ruzic    druzic@illinois.edu
# 3      warnow          Tandy            Warnow    warnow@illinois.edu
# 4         mfi        Michael            Insana       mfi@illinois.edu
# 5    langbort         Cedric          Langbort  langbort@illinois.edu
# 6      nikita         Nikita           Borisov    nikita@illinois.edu
# 7      wgropp        William             Gropp    wgropp@illinois.edu
# 8    cwfletch    Christopher          Fletcher  cwfletch@illinois.edu
# 9     roydong            Roy              Dong   roydong@illinois.edu
# 10       nies        Shuming               Nie      nies@illinois.edu
# 11        cdp    Constantine  Polychronopoulos       cdp@illinois.edu
# 12    dmnicol          David             Nicol   dmnicol@illinois.edu
# 13   kevinkim       Kyekyoon               Kim  kevinkim@illinois.edu
# 14   turnbull         Robert          Turnbull  turnbull@illinois.edu
# 15    cradhak  Chandrasekhar     Radhakrishnan   cradhak@illinois.edu
# 16       nagi         Rakesh              Nagi      nagi@illinois.edu
# 17   jbentsma         Joseph          Bentsman  jbentsma@illinois.edu
# 18                   Charles         Hendricks
# 19   klevchen         Kirill         Levchenko  klevchen@illinois.edu
# 20    angelia        Angelia            Nedich   angelia@illinois.edu
# 21    jrogers           John            Rogers   jrogers@illinois.edu
# 22      paris          Paris         Smaragdis     paris@illinois.edu
# 23    jinjunx         Jinjun             Xiong   jinjunx@illinois.edu
# 24     oakley          Burks                II    oakley@illinois.edu
# 25     ywchen         Yuting              Chen    ywchen@illinois.edu
# 26   ktoussai         Kimani         Toussaint  ktoussai@illinois.edu
# 27       kesh             T.         Kesavadas      kesh@illinois.edu
# 28   p-ransom        Preston            Ransom  p-ransom@illinois.edu
# 29    alvarez           Juan           Alvarez   alvarez@illinois.edu
# ..        ...            ...               ...                    ...
# 232  wrnorris            Bob            Norris  wrnorris@illinois.edu
# 233    kirlik           Alex            Kirlik    kirlik@illinois.edu
# 234    minhdo           Minh                Do    minhdo@illinois.edu
# 235       rhk          Robin           Kravets       rhk@illinois.edu
# 236  choquett           Kent         Choquette  choquett@illinois.edu
# 237  voulgari         Petros         Voulgaris  voulgari@illinois.edu
# 238     sibin          Sibin             Mohan     sibin@illinois.edu
# 239  abusufah          Walid         Abu-Sufah  abusufah@illinois.edu
# 240  jhdzhang        Jianhua             Zhang  jhdzhang@illinois.edu
# 241   haitham        Haitham      Al-Hassanieh   haitham@illinois.edu
# 242   jinzhou            Jin              Zhou   jinzhou@illinois.edu
# 243     kesan            Jay             Kesan     kesan@illinois.edu
# 244   pramodv         Pramod         Viswanath   pramodv@illinois.edu
# 245    w-chew           Weng              Chew    w-chew@illinois.edu
# 246  shanbhag         Naresh          Shanbhag  shanbhag@illinois.edu
# 247  plchapma        Patrick           Chapman  plchapma@illinois.edu
# 248     songp        Pengfei              Song     songp@illinois.edu
# 249       rxb          Rohit          Bhargava       rxb@illinois.edu
# 250    mspong           Mark             Spong    mspong@illinois.edu
# 251  t-huang1         Thomas             Huang  t-huang1@illinois.edu
# 252  detemple         Thomas          DeTemple  detemple@illinois.edu
# 253       mjt          Matus         Telgarsky       mjt@illinois.edu
# 254    roydar            Roy               Dar    roydar@illinois.edu
# 255   misailo           Sasa        Misailovic   misailo@illinois.edu
# 256   zcheng1          Zuofu             Cheng   zcheng1@illinois.edu
# 257    lyding         Joseph            Lyding    lyding@illinois.edu
# 258     frizz           Leon          Frizzell     frizz@illinois.edu
# 259  bwheeler          Bruce           Wheeler  bwheeler@illinois.edu
# 260  swenson1           Gary           Swenson  swenson1@illinois.edu
# 261     dchen         Deming              Chen     dchen@illinois.edu
#
# [262 rows x 4 columns]

# %%
count = df2["Netid"].count()
faculty_netid_hash_map = {}
for i in range(count):
    netid = df2["Netid"][i]
    firstname = df2["FirstName"][i]
    lastname = df2["LastName"][i]
    faculty_netid_hash_map[netid] = [netid, firstname, lastname]
faculty_netid_hash_map
# Out:
# {' ': [' ', 'Charles', 'Hendricks'],
#  ' bitzer': [' bitzer', 'Donald', 'Bitzer'],
#  ' jbcruz': [' jbcruz', 'Jose', 'Cruz'],
#  'abusufah': ['abusufah', 'Walid', 'Abu-Sufah'],
#  'acsinger': ['acsinger', 'Andrew', 'Singer'],
#  'afliflet': ['afliflet', 'Arne', 'Fliflet'],
#  'aledan': ['aledan', 'Alejandro', 'Dominguez-Garcia'],
#  'alleyne': ['alleyne', 'Andrew', 'Alleyne'],
#  'aluru': ['aluru', 'Narayana', 'Aluru'],
#  'alvarez': ['alvarez', 'Juan', 'Alvarez'],
#  'andreask': ['andreask', 'Andreas', 'Kloeckner'],
#  'angelia': ['angelia', 'Angelia', 'Nedich'],
#  'arendv': ['arendv', 'Arend', 'Zande'],
#  'arijit': ['arijit', 'Arijit', 'Banerjee'],
#  'aschwing': ['aschwing', 'Alexander', 'Schwing'],
#  'ashlynn': ['ashlynn', 'Ashlynn', 'Stillwell'],
#  'avouris': ['avouris', 'Phaedon', 'Avouris'],
#  'b-hajek': ['b-hajek', 'Bruce', 'Hajek'],
#  'bahl': ['bahl', 'Gaurav', 'Bahl'],
#  'basar1': ['basar1', 'Tamer', 'Ba\xc5\x9far'],
#  'batesa': ['batesa', 'Adam', 'Bates'],
#  'bcunning': ['bcunning', 'Brian', 'Cunningham'],
#  'beck3': ['beck3', 'Carolyn', 'Beck'],
#  'belabbas': ['belabbas', 'Mohamed', 'Belabbas'],
#  'bhorst': ['bhorst', 'Robert', 'Horst'],
#  'bigdog': ['bigdog', 'Robert', 'Brunner'],
#  'binhu7': ['binhu7', 'Bin', 'Hu'],
#  'blahut': ['blahut', 'Richard', 'Blahut'],
#  'boppart': ['boppart', 'Stephen', 'Boppart'],
#  'boses': ['boses', 'Subhonmesh', 'Bose'],
#  'bsutton': ['bsutton', 'Brad', 'Sutton'],
#  'butala': ['butala', 'Mark', 'Butala'],
#  'bwheeler': ['bwheeler', 'Bruce', 'Wheeler'],
#  'caesar': ['caesar', 'Matthew', 'Caesar'],
#  'cangella': ['cangella', 'Andreas', 'Cangellaris'],
#  'carney': ['carney', 'P.', 'Carney'],
#  'cbayram': ['cbayram', 'Can', 'Bayram'],
#  'cdp': ['cdp', 'Constantine', 'Polychronopoulos'],
#  'cdschmit': ['cdschmit', 'Christopher', 'Schmitz'],
#  'cgardner': ['cgardner', 'Chester', 'Gardner'],
#  'chadjic': ['chadjic', 'Christoforos', 'Hadjicostis'],
#  'choquett': ['choquett', 'Kent', 'Choquette'],
#  'cradhak': ['cradhak', 'Chandrasekhar', 'Radhakrishnan'],
#  'croy': ['croy', 'Romit', 'Choudhury'],
#  'cwfletch': ['cwfletch', 'Christopher', 'Fletcher'],
#  'daf': ['daf', 'David', 'Forsyth'],
#  'danr': ['danr', 'Dan', 'Roth'],
#  'davekirk': ['davekirk', 'David', 'Kirk'],
#  'dchen': ['dchen', 'Deming', 'Chen'],
#  'detemple': ['detemple', 'Thomas', 'DeTemple'],
#  'dhoiem': ['dhoiem', 'Derek', 'Hoiem'],
#  'djb': ['djb', 'Donna', 'Brown'],
#  'dl-jones': ['dl-jones', 'Douglas', 'Jones'],
#  'dmnicol': ['dmnicol', 'David', 'Nicol'],
#  'dokmanic': ['dokmanic', 'Ivan', 'Dokmanic'],
#  'druzic': ['druzic', 'David', 'Ruzic'],
#  'dskatz': ['dskatz', 'Daniel', 'Katz'],
#  'dullerud': ['dullerud', 'Geir', 'Dullerud'],
#  'echitamb': ['echitamb', 'Eric', 'Chitambar'],
#  'elyse': ['elyse', 'Elyse', 'Rosenbaum'],
#  'erhan': ['erhan', 'Erhan', 'Kudeki'],
#  'fanlam1': ['fanlam1', 'Fan', 'Lam'],
#  'farzadk': ['farzadk', 'Farzad', 'Kamalabadi'],
#  'frizz': ['frizz', 'Leon', 'Frizzell'],
#  'gaol': ['gaol', 'Liang', 'Gao'],
#  'girishc': ['girishc', 'Girish', 'Chowdhary'],
#  'gpopescu': ['gpopescu', 'Gabriel', 'Popescu'],
#  'gracegao': ['gracegao', 'Grace', 'Gao'],
#  'gross': ['gross', 'George', 'Gross'],
#  'haitham': ['haitham', 'Haitham', 'Al-Hassanieh'],
#  'han51': ['han51', 'Aiguo', 'Han'],
#  'hanj': ['hanj', 'Jiawei', 'Han'],
#  'hanumolu': ['hanumolu', 'Pavan', 'Hanumolu'],
#  'haozhu': ['haozhu', 'Hao', 'Zhu'],
#  'hillmer': ['hillmer', 'Philip', 'Hillmer'],
#  'hshi10': ['hshi10', 'Humphrey', 'Shi'],
#  'hyungsoo': ['hyungsoo', 'Hyungsoo', 'Choi'],
#  'iadesida': ['iadesida', 'Ilesanmi', 'Adesida'],
#  'idoia': ['idoia', 'Idoia', 'Ochoa'],
#  'ihajj': ['ihajj', 'Ibrahim', 'Hajj'],
#  'ilans': ['ilans', 'Ilan', 'Shomorony'],
#  'indy': ['indy', 'Indranil', 'Gupta'],
#  'j-jin1': ['j-jin1', 'Jianming', 'Jin'],
#  'jbentsma': ['jbentsma', 'Joseph', 'Bentsman'],
#  'jbernhar': ['jbernhar', 'Jennifer', 'Bernhard'],
#  'jcoleman': ['jcoleman', 'James', 'Coleman'],
#  'jdallesa': ['jdallesa', 'John', 'Dallesasse'],
#  'jesa': ['jesa', 'Jose', 'Schutt-Aine'],
#  'jgeden': ['jgeden', 'J.', 'Eden'],
#  'jhasegaw': ['jhasegaw', 'Mark', 'Hasegawa-Johnson'],
#  'jhdzhang': ['jhdzhang', 'Jianhua', 'Zhang'],
#  'jhpatel': ['jhpatel', 'Janak', 'Patel'],
#  'jianh': ['jianh', 'Jian', 'Huang'],
#  'jianzuo': ['jianzuo', 'Jian-Min', 'Zuo'],
#  'jinjunx': ['jinjunx', 'Jinjun', 'Xiong'],
#  'jinzhou': ['jinzhou', 'Jin', 'Zhou'],
#  'jleburto': ['jleburto', 'Jean-Pierre', 'Leburton'],
#  'jmakela': ['jmakela', 'Jonathan', 'Makela'],
#  'jontalle': ['jontalle', 'Jont', 'Allen'],
#  'jraman': ['jraman', 'Jaishankar', 'Raman'],
#  'jrogers': ['jrogers', 'John', 'Rogers'],
#  'jwbeauch': ['jwbeauch', 'James', 'Beauchamp'],
#  'kalbarcz': ['kalbarcz', 'Zbigniew', 'Kalbarczyk'],
#  'kang': ['kang', 'Sung', 'Kang'],
#  'katselis': ['katselis', 'Dimitrios', 'Katselis'],
#  'kcchang': ['kcchang', 'Kevin', 'Chang'],
#  'kesan': ['kesan', 'Jay', 'Kesan'],
#  'kesh': ['kesh', 'T.', 'Kesavadas'],
#  'kevinkim': ['kevinkim', 'Kyekyoon', 'Kim'],
#  'kfang3': ['kfang3', 'Kejie', 'Fang'],
#  'kharan': ['kharan', 'Kiruba', 'Haran'],
#  'khsieh': ['khsieh', 'Kuang-Chien', 'Hsieh'],
#  'kindrtnk': ['kindrtnk', 'Volodymyr', 'Kindratenko'],
#  'kirlik': ['kirlik', 'Alex', 'Kirlik'],
#  'kjain': ['kjain', 'Kanti', 'Jain'],
#  'kkarahal': ['kkarahal', 'Karrie', 'Karahalios'],
#  'klara': ['klara', 'Klara', 'Nahrstedt'],
#  'klevchen': ['klevchen', 'Kirill', 'Levchenko'],
#  'krdc': ['krdc', 'Katherine', 'Driggs-Campbell'],
#  'krein': ['krein', 'Philip', 'Krein'],
#  'krogers6': ['krogers6', 'Katherine', 'Davis'],
#  'ktoussai': ['ktoussai', 'Kimani', 'Toussaint'],
#  'kwiat': ['kwiat', 'Paul', 'Kwiat'],
#  'kycheng': ['kycheng', 'Keh-Yung', 'Cheng'],
#  'l-haken': ['l-haken', 'Lippold', 'Haken'],
#  'langbort': ['langbort', 'Cedric', 'Langbort'],
#  'lavalle': ['lavalle', 'Steven', 'LaValle'],
#  'lgoddard': ['lgoddard', 'Lynford', 'Goddard'],
#  'lgurel': ['lgurel', 'Levent', 'Gurel'],
#  'liberzon': ['liberzon', 'Daniel', 'Liberzon'],
#  'liuzr': ['liuzr', 'Zhuangren', 'Liu'],
#  'loui': ['loui', 'Michael', 'Loui'],
#  'lrs': ['lrs', 'Lui', 'Sha'],
#  'lumetta': ['lumetta', 'Steven', 'Lumetta'],
#  'lwaldrop': ['lwaldrop', 'Lara', 'Waldrop'],
#  'lyding': ['lyding', 'Joseph', 'Lyding'],
#  'maa': ['maa', 'Mark', 'Anastasio'],
#  'mapai': ['mapai', 'M.', 'Pai'],
#  'matthewg': ['matthewg', 'Matthew', 'Gilbert'],
#  'maxim': ['maxim', 'Maxim', 'Raginsky'],
#  'mcaccamo': ['mcaccamo', 'Marco', 'Caccamo'],
#  'mdbailey': ['mdbailey', 'Michael', 'Bailey'],
#  'mdfwong': ['mdfwong', 'Martin', 'Wong'],
#  'mehtapg': ['mehtapg', 'Prashant', 'Mehta'],
#  'meisongt': ['meisongt', 'Meisong', 'Tong'],
#  'mfeng': ['mfeng', 'Milton', 'Feng'],
#  'mfi': ['mfi', 'Michael', 'Insana'],
#  'milenkov': ['milenkov', 'Olgica', 'Milenkovic'],
#  'minhdo': ['minhdo', 'Minh', 'Do'],
#  'misailo': ['misailo', 'Sasa', 'Misailovic'],
#  'mitras': ['mitras', 'Sayan', 'Mitra'],
#  'mjt': ['mjt', 'Matus', 'Telgarsky'],
#  'mllee': ['mllee', 'Minjoo', 'Lee'],
#  'mspong': ['mspong', 'Mark', 'Spong'],
#  'n-ahuja': ['n-ahuja', 'Narendra', 'Ahuja'],
#  'nagi': ['nagi', 'Rakesh', 'Nagi'],
#  'nanjiang': ['nanjiang', 'Nan', 'Jiang'],
#  'nholonya': ['nholonya', 'Nick', 'Jr'],
#  'nhovakim': ['nhovakim', 'Naira', 'Hovakimyan'],
#  'nhv': ['nhv', 'Nitin', 'Vaidya'],
#  'niaohe': ['niaohe', 'Niao', 'He'],
#  'nies': ['nies', 'Shuming', 'Nie'],
#  'nikita': ['nikita', 'Nikita', 'Borisov'],
#  'nmiljkov': ['nmiljkov', 'Nenad', 'Miljkovic'],
#  'nnrao': ['nnrao', 'N.', 'Rao'],
#  'npcarter': ['npcarter', 'Nicholas', 'Carter'],
#  'oakley': ['oakley', 'Burks', 'II'],
#  'oelze': ['oelze', 'Michael', 'Oelze'],
#  'overbye': ['overbye', 'Thomas', 'Overbye'],
#  'p-dragic': ['p-dragic', 'Peter', 'Dragic'],
#  'p-ransom': ['p-ransom', 'Preston', 'Ransom'],
#  'paris': ['paris', 'Paris', 'Smaragdis'],
#  'pbg': ['pbg', 'Philip', 'Godfrey'],
#  'pilawa': ['pilawa', 'Robert', 'Pilawa-Podgurski'],
#  'plchapma': ['plchapma', 'Patrick', 'Chapman'],
#  'pmoulin': ['pmoulin', 'Pierre', 'Moulin'],
#  'pramodv': ['pramodv', 'Pramod', 'Viswanath'],
#  'prkumar': ['prkumar', 'P.', 'Kumar'],
#  'psauer': ['psauer', 'Peter', 'Sauer'],
#  'qingcao2': ['qingcao2', 'Qing', 'Cao'],
#  'r-uribe': ['r-uribe', 'Ricardo', 'Uribe'],
#  'radhikam': ['radhikam', 'Radhika', 'Mittal'],
#  'rakeshk': ['rakeshk', 'Rakesh', 'Kumar'],
#  'ranjitha': ['ranjitha', 'Ranjitha', 'Kumar'],
#  'ravaioli': ['ravaioli', 'Umberto', 'Ravaioli'],
#  'rbashir': ['rbashir', 'Rashid', 'Bashir'],
#  'rhk': ['rhk', 'Robin', 'Kravets'],
#  'rilie': ['rilie', 'Raluca', 'Ilie'],
#  'rkiyer': ['rkiyer', 'Ravishankar', 'Iyer'],
#  'roydar': ['roydar', 'Roy', 'Dar'],
#  'roydong': ['roydong', 'Roy', 'Dong'],
#  'rsree': ['rsree', 'Ramavarapu', 'Sreenivas'],
#  'rsrikant': ['rsrikant', 'Rayadurgam', 'Srikant'],
#  'ruoyus': ['ruoyus', 'Ruoyu', 'Sun'],
#  'rutenbar': ['rutenbar', 'Rob', 'Rutenbar'],
#  'rxb': ['rxb', 'Rohit', 'Bhargava'],
#  'ryz': ['ryz', 'Richard', 'Zhang'],
#  's-franke': ['s-franke', 'Steven', 'Franke'],
#  'sadve': ['sadve', 'Sarita', 'Adve'],
#  'sanmi': ['sanmi', 'Sanmi', 'Koyejo'],
#  'sarwate': ['sarwate', 'Dilip', 'Sarwate'],
#  'saurabhg': ['saurabhg', 'Saurabh', 'Gupta'],
#  'selevins': ['selevins', 'Stephen', 'Levinson'],
#  'seth': ['seth', 'Seth', 'Hutchinson'],
#  'sgbishop': ['sgbishop', 'Stephen', 'Bishop'],
#  'shanbhag': ['shanbhag', 'Naresh', 'Shanbhag'],
#  'shj': ['shj', 'Sheldon', 'Jacobson'],
#  'shobhav': ['shobhav', 'Shobha', 'Vasudevan'],
#  'sibin': ['sibin', 'Sibin', 'Mohan'],
#  'sjinpark': ['sjinpark', 'Sung-Jin', 'Park'],
#  'sjp': ['sjp', 'Sanjay', 'Patel'],
#  'soc1024': ['soc1024', 'Andrew', 'Miller'],
#  'songbin': ['songbin', 'Songbin', 'Gong'],
#  'songp': ['songp', 'Pengfei', 'Song'],
#  'spbhat2': ['spbhat2', 'Suma', 'Bhat'],
#  'stolyar': ['stolyar', 'Alexander', 'Stolyar'],
#  'stratton': ['stratton', 'John', 'Stratton'],
#  'swenson1': ['swenson1', 'Gary', 'Swenson'],
#  'swoh': ['swoh', 'Sewoong', 'Oh'],
#  't-huang1': ['t-huang1', 'Thomas', 'Huang'],
#  'tangul': ['tangul', 'Tangul', 'Basar'],
#  'tbretl': ['tbretl', 'Timothy', 'Bretl'],
#  'tcoconne': ['tcoconne', 'Timothy', "O'Connell"],
#  'thuang19': ['thuang19', 'Tsung-Wei', 'Huang'],
#  'tkilleen': ['tkilleen', 'Timothy', 'Killeen'],
#  'torrella': ['torrella', 'Josep', 'Torrellas'],
#  'ttrick': ['ttrick', 'Timothy', 'Trick'],
#  'turnbull': ['turnbull', 'Robert', 'Turnbull'],
#  'ubhowmik': ['ubhowmik', 'Ujjal', 'Bhowmik'],
#  'varshney': ['varshney', 'Lav', 'Varshney'],
#  'vgruev': ['vgruev', 'Viktor', 'Gruev'],
#  'voulgari': ['voulgari', 'Petros', 'Voulgaris'],
#  'vvv': ['vvv', 'Venugopal', 'Veeravalli'],
#  'w-chew': ['w-chew', 'Weng', 'Chew'],
#  'w-hwu': ['w-hwu', 'Wen-mei', 'Hwu'],
#  'wah': ['wah', 'Benjamin', 'Wah'],
#  'warnow': ['warnow', 'Tandy', 'Warnow'],
#  'wdo': ['wdo', 'William', 'Jr.'],
#  'weihe16': ['weihe16', 'Wei', 'He'],
#  'wgropp': ['wgropp', 'William', 'Gropp'],
#  'whs': ['whs', 'William', 'Sanders'],
#  'wjzhu': ['wjzhu', 'Wenjuan', 'Zhu'],
#  'wperkins': ['wperkins', 'William', 'Perkins'],
#  'wpk': ['wpk', 'Bill', 'King'],
#  'wrnorris': ['wrnorris', 'Bob', 'Norris'],
#  'wuebbles': ['wuebbles', 'Donald', 'Wuebbles'],
#  'xiuling': ['xiuling', 'Xiuling', 'Li'],
#  'xuchen1': ['xuchen1', 'Xu', 'Chen'],
#  'ybresler': ['ybresler', 'Yoram', 'Bresler'],
#  'yihchun': ['yihchun', 'Yih-Chun', 'Hu'],
#  'yihongwu': ['yihongwu', 'Yihong', 'Wu'],
#  'yilu4': ['yilu4', 'Yi', 'Lu'],
#  'ymb': ['ymb', 'Yuliy', 'Baryshnikov'],
#  'yunsheng': ['yunsheng', 'Yun-Sheng', 'Chen'],
#  'yvlasov': ['yvlasov', 'Yurii', 'Vlasov'],
#  'ywchen': ['ywchen', 'Yuting', 'Chen'],
#  'yzhaoui': ['yzhaoui', 'Yang', 'Zhao'],
#  'z-liang': ['z-liang', 'Zhi-Pei', 'Liang'],
#  'zcheng1': ['zcheng1', 'Zuofu', 'Cheng'],
#  'zhizhenz': ['zhizhenz', 'Zhizhen', 'Zhao'],
#  'zhyang': ['zhyang', 'Yang', 'Zhang'],
#  'zilles': ['zilles', 'Craig', 'Zilles']}

# %% [markdown]
# add another column for netid in courses

# %%
count = df["Course"].count()
hash_map_final = {}

for i in range(count):
    value = df["Instructor"][i]
    key = df["Course"][i]
    term = df["Term"][i]
    title = df["Title"][i]
    netid = ""
    if key not in hash_map_final:
        hash_map_final[key] = [key, value, term, title, netid]
hash_map_final
# Out:
# {'ECE-101': ['ECE-101',
#   'Schmitz, Christopher',
#   '2013-sp',
#   'Exploring Digital Info Technol',
#   ''],
#  'ECE-110': ['ECE-110',
#   'Schmitz, Christopher',
#   '2018-fa',
#   'Introduction to Electronics',
#   ''],
#  'ECE-120': ['ECE-120',
#   'Kindratenko, Volodymyr',
#   '2018-fa',
#   'Introduction to Computing',
#   ''],
#  'ECE-190': ['ECE-190',
#   'Hu, Yih-Chun',
#   '2013-fa',
#   'Intro to Computing Systems',
#   ''],
#  'ECE-198': ['ECE-198',
#   'Kindratenko, Volodymyr',
#   '2014-fa',
#   'Introduction to Computer Eng',
#   ''],
#  'ECE-199': ['ECE-199',
#   'Varodayan, David',
#   '2018-fa',
#   'Undergraduate Open Seminar',
#   ''],
#  'ECE-205': ['ECE-205',
#   'Radhakrishnan, Chandrasek',
#   '2018-fa',
#   'Electrical & Electronic Ckts',
#   ''],
#  'ECE-206': ['ECE-206',
#   'Radhakrishnan, Chandrasek',
#   '2018-fa',
#   'Electrical & Electronics Lab',
#   ''],
#  'ECE-210': ['ECE-210',
#   'Alvarez, Juan',
#   '2018-fa',
#   'Analog Signal Processing',
#   ''],
#  'ECE-220': ['ECE-220',
#   'Chen, Yuting W',
#   '2018-fa',
#   'Computer Systems & Programming',
#   ''],
#  'ECE-290': ['ECE-290',
#   'Brown, Donna J',
#   '2014-sp',
#   'Computer Engineering I',
#   ''],
#  'ECE-298': ['ECE-298',
#   'Allen, Jont',
#   '2017-fa',
#   'Concepts in Engineering Math',
#   ''],
#  'ECE-304': ['ECE-304',
#   'Choquette, Kent D',
#   '2018-fa',
#   'Photonic Devices',
#   ''],
#  'ECE-307': ['ECE-307',
#   'Gross, George',
#   '2016-sp',
#   'Techniques for Engrg Decisions',
#   ''],
#  'ECE-310': ['ECE-310',
#   'Shomorony, Ilan',
#   '2018-fa',
#   'Digital Signal Processing',
#   ''],
#  'ECE-311': ['ECE-311',
#   'Bresler, Yoram',
#   '2018-fa',
#   'Digital Signal Processing Lab',
#   ''],
#  'ECE-313': ['ECE-313',
#   'Veeravalli, Venugopal V',
#   '2018-fa',
#   'Probability with Engrg Applic',
#   ''],
#  'ECE-314': ['ECE-314',
#   'Hajek, Bruce',
#   '2018-fa',
#   'Probability in Engineering Lab',
#   ''],
#  'ECE-316': ['ECE-316',
#   'Hillmer, Philip M',
#   '2018-fa',
#   'Ethics and Engineering',
#   ''],
#  'ECE-317': ['ECE-317',
#   'He, Wei',
#   '2018-sp',
#   'ECE Technology & Management',
#   ''],
#  'ECE-329': ['ECE-329', 'Waldrop, Lara', '2018-fa', 'Fields and Waves I', ''],
#  'ECE-330': ['ECE-330',
#   'Schuh, Jonathon K',
#   '2018-fa',
#   'Power Ckts & Electromechanics',
#   ''],
#  'ECE-333': ['ECE-333',
#   'Gross, George',
#   '2018-fa',
#   'Green Electric Energy',
#   ''],
#  'ECE-340': ['ECE-340',
#   'Dallesasse, John M',
#   '2018-fa',
#   'Semiconductor Electronics',
#   ''],
#  'ECE-342': ['ECE-342', 'Zhou, Jin', '2018-fa', 'Electronic Circuits', ''],
#  'ECE-343': ['ECE-343',
#   'Radhakrishnan, Chandrasek',
#   '2018-sp',
#   'Electronic Circuits Laboratory',
#   ''],
#  'ECE-350': ['ECE-350', 'Gong, Songbin', '2018-sp', 'Fields and Waves II', ''],
#  'ECE-361': ['ECE-361',
#   'Alvarez, Juan',
#   '2017-sp',
#   'Digital Communications',
#   ''],
#  'ECE-380': ['ECE-380',
#   'Boppart, Stephen A',
#   '2018-fa',
#   'Biomedical Imaging',
#   ''],
#  'ECE-385': ['ECE-385',
#   'Cheng, Zuofu',
#   '2018-fa',
#   'Digital Systems Laboratory',
#   ''],
#  'ECE-391': ['ECE-391',
#   'Kalbarczyk, Zbigniew T',
#   '2018-fa',
#   'Computer Systems Engineering',
#   ''],
#  'ECE-395': ['ECE-395',
#   'Haken, Lippold',
#   '2017-sp',
#   'Advanced Digital Projects Lab',
#   ''],
#  'ECE-398': ['ECE-398',
#   'Do, Minh N',
#   '2018-fa',
#   'Making Sense of Big Data',
#   ''],
#  'ECE-401': ['ECE-401',
#   'Hasegawa-Johnso, Mark A',
#   '2017-sp',
#   'Signal and Image Analysis',
#   ''],
#  'ECE-402': ['ECE-402',
#   'Haken, Lippold',
#   '2018-fa',
#   'Electronic Music Synthesis',
#   ''],
#  'ECE-403': ['ECE-403',
#   'Smaragdis, Paris',
#   '2014-sp',
#   'Audio Engineering',
#   ''],
#  'ECE-408': ['ECE-408',
#   'Patel, Sanjay J',
#   '2018-fa',
#   'Applied Parallel Programming',
#   ''],
#  'ECE-410': ['ECE-410',
#   'Singer, Andrew C',
#   '2011-sp',
#   'Digital Signal Processing I',
#   ''],
#  'ECE-411': ['ECE-411',
#   'Kumar, Rakesh',
#   '2018-fa',
#   'Computer Organization & Design',
#   ''],
#  'ECE-416': ['ECE-416', 'Cunningham, Brian T', '2018-sp', 'Biosensors', ''],
#  'ECE-417': ['ECE-417',
#   'Hasegawa-Johnso, Mark A',
#   '2018-fa',
#   'Multimedia Signal Processing',
#   ''],
#  'ECE-418': ['ECE-418',
#   'Moulin, Pierre',
#   '2017-sp',
#   'Image & Video Processing',
#   ''],
#  'ECE-420': ['ECE-420',
#   'Levinson, Stephen E',
#   '2018-sp',
#   'Embedded DSP Laboratory',
#   ''],
#  'ECE-425': ['ECE-425',
#   'Kindratenko, Volodymyr',
#   '2017-fa',
#   'Intro to VLSI System Design',
#   ''],
#  'ECE-430': ['ECE-430',
#   'Bazzi, Ali M',
#   '2011-sp',
#   'Power Ckts & Electromechanics',
#   ''],
#  'ECE-431': ['ECE-431',
#   'Haran, Kiruba S',
#   '2018-sp',
#   'Electric Machinery',
#   ''],
#  'ECE-435': ['ECE-435',
#   'Caesar, Matthew C',
#   '2018-fa',
#   'Computer Networking Laboratory',
#   ''],
#  'ECE-437': ['ECE-437',
#   'Gruev, Viktor',
#   '2018-fa',
#   'Sensors and Instrumentation',
#   ''],
#  'ECE-439': ['ECE-439',
#   'Roy Choudhury, Romit',
#   '2017-fa',
#   'Wireless Networks',
#   ''],
#  'ECE-440': ['ECE-440',
#   'Liu, Gang L',
#   '2011-sp',
#   'Solid State Electronic Devices',
#   ''],
#  'ECE-441': ['ECE-441',
#   'Zhu, Wenjuan',
#   '2018-sp',
#   'Physcs & Modeling Semicond Dev',
#   ''],
#  'ECE-442': ['ECE-442',
#   'Rosenbaum, Elyse',
#   '2011-sp',
#   'Electronic Circuits',
#   ''],
#  'ECE-443': ['ECE-443',
#   'Zhang, Jianhua',
#   '2010-fa',
#   'Electronic Circuits Laboratory',
#   ''],
#  'ECE-444': ['ECE-444',
#   'Li, Xiuling',
#   '2018-fa',
#   'IC Device Theory & Fabrication',
#   ''],
#  'ECE-445': ['ECE-445',
#   'Fliflet, Arne W',
#   '2018-fa',
#   'Senior Design Project Lab',
#   ''],
#  'ECE-447': ['ECE-447',
#   'Gong, Songbin',
#   '2016-fa',
#   'Active Microwave Ckt Design',
#   ''],
#  'ECE-450': ['ECE-450',
#   'Kudeki, Erhan',
#   '2011-sp',
#   'Lines, Fields, and Waves',
#   ''],
#  'ECE-451': ['ECE-451',
#   'Schutt-Aine, Jose E',
#   '2017-sp',
#   'Adv Microwave Measurements',
#   ''],
#  'ECE-452': ['ECE-452',
#   'Chew, Weng C',
#   '2014-fa',
#   'Electromagnetic Fields',
#   ''],
#  'ECE-453': ['ECE-453',
#   'Franke, Steven J',
#   '2018-sp',
#   'Wireless Communication Systems',
#   ''],
#  'ECE-454': ['ECE-454', 'Kudeki, Erhan', '2018-sp', 'Antennas', ''],
#  'ECE-455': ['ECE-455', 'Eden, James G', '2018-fa', 'Optical Electronics', ''],
#  'ECE-456': ['ECE-456',
#   'Gao, Xingxin',
#   '2016-fa',
#   'Global Nav Satellite Systems',
#   ''],
#  'ECE-457': ['ECE-457',
#   'Gong, Songbin',
#   '2017-sp',
#   'Microwave Devices & Circuits',
#   ''],
#  'ECE-458': ['ECE-458',
#   'Kudeki, Erhan',
#   '2010-sp',
#   'Applic of Radio Wave Propag',
#   ''],
#  'ECE-459': ['ECE-459',
#   'Alvarez, Juan',
#   '2016-fa',
#   'Communications Systems',
#   ''],
#  'ECE-461': ['ECE-461',
#   'Viswanath, Pramod',
#   '2018-sp',
#   'Digital Communications',
#   ''],
#  'ECE-462': ['ECE-462', 'Chen, Deming', '2018-sp', 'Logic Synthesis', ''],
#  'ECE-464': ['ECE-464',
#   'Banerjee, Arijit',
#   '2018-fa',
#   'Power Electronics',
#   ''],
#  'ECE-468': ['ECE-468',
#   'Waldrop, Lara',
#   '2018-sp',
#   'Optical Remote Sensing',
#   ''],
#  'ECE-469': ['ECE-469',
#   'Banerjee, Arijit',
#   '2018-fa',
#   'Power Electronics Laboratory',
#   ''],
#  'ECE-470': ['ECE-470',
#   'Belabbas, Mohamed Ali',
#   '2018-fa',
#   'Introduction to Robotics',
#   ''],
#  'ECE-473': ['ECE-473',
#   'Oelze, Michael L',
#   '2017-fa',
#   'Fund of Engrg Acoustics',
#   ''],
#  'ECE-476': ['ECE-476',
#   'Dominguez-Garci, Alejandr',
#   '2018-fa',
#   'Power System Analysis',
#   ''],
#  'ECE-480': ['ECE-480',
#   'Liang, Zhi-Pei',
#   '2018-fa',
#   'Magnetic Resonance Imaging',
#   ''],
#  'ECE-481': ['ECE-481', 'Lyding, Joseph W', '2018-sp', 'Nanotechnology', ''],
#  'ECE-482': ['ECE-482',
#   'Shanbhag, Naresh R',
#   '2018-fa',
#   'Digital IC Design',
#   ''],
#  'ECE-483': ['ECE-483',
#   'Hanumolu, Pavan Kumar',
#   '2018-sp',
#   'Analog IC Design',
#   ''],
#  'ECE-485': ['ECE-485',
#   'Liu, Gang L',
#   '2017-fa',
#   'MEMS Devices & Systems',
#   ''],
#  'ECE-486': ['ECE-486', 'Raginsky, Maxim', '2018-fa', 'Control Systems', ''],
#  'ECE-488': ['ECE-488',
#   'Dallesasse, John M',
#   '2018-fa',
#   'Compound Semicond & Devices',
#   ''],
#  'ECE-490': ['ECE-490',
#   'Hu, Bin',
#   '2018-fa',
#   'Introduction to Optimization',
#   ''],
#  'ECE-498': ['ECE-498',
#   'Levchenko, Kirill I',
#   '2018-fa',
#   'eCrime & Internet Serv Abuse',
#   ''],
#  'ECE-508': ['ECE-508',
#   'Hwu, Wen-Mei W',
#   '2017-sp',
#   'Manycore Parallel Algorithms',
#   ''],
#  'ECE-510': ['ECE-510',
#   'Jain, Kanti',
#   '2013-fa',
#   'Micro and Nanolithography',
#   ''],
#  'ECE-511': ['ECE-511',
#   'Kim, Nam Sung',
#   '2016-fa',
#   'Computer Architecture',
#   ''],
#  'ECE-515': ['ECE-515',
#   'Baryshnikov, Yuliy',
#   '2018-fa',
#   'Control System Theory & Design',
#   ''],
#  'ECE-517': ['ECE-517',
#   'Liberzon, Daniel M',
#   '2018-fa',
#   'Nonlinear & Adaptive Control',
#   ''],
#  'ECE-518': ['ECE-518',
#   'Li, Xiuling',
#   '2017-fa',
#   'Adv Semiconductor Nanotech',
#   ''],
#  'ECE-520': ['ECE-520',
#   'Jin, Jianming',
#   '2018-fa',
#   'EM Waves & Radiating Systems',
#   ''],
#  'ECE-526': ['ECE-526',
#   'Vaidya, Nitin H',
#   '2016-fa',
#   'Distributed Algorithms',
#   ''],
#  'ECE-527': ['ECE-527',
#   'Chen, Deming',
#   '2018-fa',
#   'System-On-Chip Design',
#   ''],
#  'ECE-528': ['ECE-528',
#   'Stipanovic, Dusan M',
#   '2017-sp',
#   'Analysis of Nonlinear Systems',
#   ''],
#  'ECE-532': ['ECE-532',
#   'Choquette, Kent D',
#   '2013-fa',
#   'Compnd Semicond & Diode Lasers',
#   ''],
#  'ECE-534': ['ECE-534',
#   'Milenkovic, Olgica',
#   '2018-fa',
#   'Random Processes',
#   ''],
#  'ECE-535': ['ECE-535',
#   'Leburton, Jean-Pierre',
#   '2016-fa',
#   'Theory of Semicond & Devices',
#   ''],
#  'ECE-536': ['ECE-536',
#   'Chuang, Shun L',
#   '2011-sp',
#   'Integ Optics & Optoelectronics',
#   ''],
#  'ECE-541': ['ECE-541',
#   'Noureddine, Mohammad',
#   '2018-fa',
#   'Computer Systems Analysis',
#   ''],
#  'ECE-543': ['ECE-543',
#   'Raginsky, Maxim',
#   '2018-sp',
#   'Statistical Learning Theory',
#   ''],
#  'ECE-544': ['ECE-544',
#   'Schwing, Alexander G',
#   '2018-fa',
#   'Pattern Recognition',
#   ''],
#  'ECE-546': ['ECE-546',
#   'Schutt-Aine, Jose E',
#   '2018-sp',
#   'Advanced Signal Integrity',
#   ''],
#  'ECE-547': ['ECE-547',
#   'Schwing, Alexander G',
#   '2017-sp',
#   'Topics in Image Processing',
#   ''],
#  'ECE-549': ['ECE-549',
#   'Lazebnik, Svetlana',
#   '2018-sp',
#   'Computer Vision',
#   ''],
#  'ECE-550': ['ECE-550',
#   'Hutchinson, Seth A',
#   '2016-sp',
#   'Advanced Robotic Planning',
#   ''],
#  'ECE-551': ['ECE-551',
#   'Dokmanic, Ivan',
#   '2018-fa',
#   'Digital Signal Processing II',
#   ''],
#  'ECE-553': ['ECE-553',
#   'Liberzon, Daniel M',
#   '2013-sp',
#   'Optimum Control Systems',
#   ''],
#  'ECE-554': ['ECE-554',
#   'Dominguez-Garci, Alejandr',
#   '2015-sp',
#   'Dynamic System Reliability',
#   ''],
#  'ECE-561': ['ECE-561',
#   'Veeravalli, Venugopal V',
#   '2014-sp',
#   'Detection & Estimation Theory',
#   ''],
#  'ECE-563': ['ECE-563',
#   'Varshney, Lav R',
#   '2018-fa',
#   'Information Theory',
#   ''],
#  'ECE-564': ['ECE-564',
#   'Popescu, Gabriel',
#   '2015-sp',
#   'Modern Light Microscopy',
#   ''],
#  'ECE-566': ['ECE-566',
#   'Moulin, Pierre',
#   '2018-fa',
#   'Computational Inference',
#   ''],
#  'ECE-569': ['ECE-569',
#   'Carney, Paul S',
#   '2014-fa',
#   'Inverse Problems in Optics',
#   ''],
#  'ECE-576': ['ECE-576',
#   'Overbye, Thomas J',
#   '2014-sp',
#   'Power System Dynm & Stability',
#   ''],
#  'ECE-580': ['ECE-580',
#   'Srikant, Rayadurgam',
#   '2013-fa',
#   'Optimiz by Vector Space Methds',
#   ''],
#  'ECE-581': ['ECE-581',
#   'Hanumolu, Pavan Kumar',
#   '2018-fa',
#   'Advanced Analog IC Design',
#   ''],
#  'ECE-586': ['ECE-586',
#   'Srikant, Rayadurgam',
#   '2017-fa',
#   'MDPs, Reinforcement Learning',
#   ''],
#  'ECE-598': ['ECE-598',
#   'Zhu, Wenjuan',
#   '2018-fa',
#   '2D Material Electr & Photonics',
#   '']}

# %%
count = df2["Netid"].count()
key_list = df2['Netid'].values.tolist()
newlist = list()
for i in map_.keys():
    newlist.append(i)
# print(newlist)
for i in key_list:
    netid = faculty_netid_hash_map[i][0]
    firstname = faculty_netid_hash_map[i][1]
    lastname = faculty_netid_hash_map[i][2]
    length_of_map_ = len(map_)
    for j in newlist:
        if firstname == map_[j][1] and lastname == map_[j][2]:
            key_hash_map_final = j[:7]
            hash_map_final[key_hash_map_final][4] = netid
            
print(hash_map_final)
#TODO: LOOK AT HASH MAp tp see missing netids and fill them up manually
# Out:
# {'ECE-408': ['ECE-408', 'Patel, Sanjay J', '2018-fa', 'Applied Parallel Programming', 'sjp'], 'ECE-401': ['ECE-401', 'Hasegawa-Johnso, Mark A', '2017-sp', 'Signal and Image Analysis', ''], 'ECE-403': ['ECE-403', 'Smaragdis, Paris', '2014-sp', 'Audio Engineering', 'paris'], 'ECE-402': ['ECE-402', 'Haken, Lippold', '2018-fa', 'Electronic Music Synthesis', 'l-haken'], 'ECE-481': ['ECE-481', 'Lyding, Joseph W', '2018-sp', 'Nanotechnology', 'lyding'], 'ECE-480': ['ECE-480', 'Liang, Zhi-Pei', '2018-fa', 'Magnetic Resonance Imaging', 'z-liang'], 'ECE-483': ['ECE-483', 'Hanumolu, Pavan Kumar', '2018-sp', 'Analog IC Design', 'hanumolu'], 'ECE-482': ['ECE-482', 'Shanbhag, Naresh R', '2018-fa', 'Digital IC Design', 'shanbhag'], 'ECE-485': ['ECE-485', 'Liu, Gang L', '2017-fa', 'MEMS Devices & Systems', ''], 'ECE-486': ['ECE-486', 'Raginsky, Maxim', '2018-fa', 'Control Systems', 'maxim'], 'ECE-488': ['ECE-488', 'Dallesasse, John M', '2018-fa', 'Compound Semicond & Devices', 'jdallesa'], 'ECE-333': ['ECE-333', 'Gross, George', '2018-fa', 'Green Electric Energy', 'gross'], 'ECE-120': ['ECE-120', 'Kindratenko, Volodymyr', '2018-fa', 'Introduction to Computing', 'kindrtnk'], 'ECE-330': ['ECE-330', 'Schuh, Jonathon K', '2018-fa', 'Power Ckts & Electromechanics', ''], 'ECE-511': ['ECE-511', 'Kim, Nam Sung', '2016-fa', 'Computer Architecture', ''], 'ECE-459': ['ECE-459', 'Alvarez, Juan', '2016-fa', 'Communications Systems', 'alvarez'], 'ECE-535': ['ECE-535', 'Leburton, Jean-Pierre', '2016-fa', 'Theory of Semicond & Devices', 'jleburto'], 'ECE-534': ['ECE-534', 'Milenkovic, Olgica', '2018-fa', 'Random Processes', 'milenkov'], 'ECE-536': ['ECE-536', 'Chuang, Shun L', '2011-sp', 'Integ Optics & Optoelectronics', ''], 'ECE-532': ['ECE-532', 'Choquette, Kent D', '2013-fa', 'Compnd Semicond & Diode Lasers', 'choquett'], 'ECE-554': ['ECE-554', 'Dominguez-Garci, Alejandr', '2015-sp', 'Dynamic System Reliability', ''], 'ECE-553': ['ECE-553', 'Liberzon, Daniel M', '2013-sp', 'Optimum Control Systems', 'liberzon'], 'ECE-551': ['ECE-551', 'Dokmanic, Ivan', '2018-fa', 'Digital Signal Processing II', 'dokmanic'], 'ECE-550': ['ECE-550', 'Hutchinson, Seth A', '2016-sp', 'Advanced Robotic Planning', 'seth'], 'ECE-442': ['ECE-442', 'Rosenbaum, Elyse', '2011-sp', 'Electronic Circuits', 'elyse'], 'ECE-329': ['ECE-329', 'Waldrop, Lara', '2018-fa', 'Fields and Waves I', 'lwaldrop'], 'ECE-498': ['ECE-498', 'Levchenko, Kirill I', '2018-fa', 'eCrime & Internet Serv Abuse', 'klevchen'], 'ECE-490': ['ECE-490', 'Hu, Bin', '2018-fa', 'Introduction to Optimization', 'binhu7'], 'ECE-451': ['ECE-451', 'Schutt-Aine, Jose E', '2017-sp', 'Adv Microwave Measurements', 'jesa'], 'ECE-528': ['ECE-528', 'Stipanovic, Dusan M', '2017-sp', 'Analysis of Nonlinear Systems', ''], 'ECE-520': ['ECE-520', 'Jin, Jianming', '2018-fa', 'EM Waves & Radiating Systems', 'j-jin1'], 'ECE-526': ['ECE-526', 'Vaidya, Nitin H', '2016-fa', 'Distributed Algorithms', 'nhv'], 'ECE-527': ['ECE-527', 'Chen, Deming', '2018-fa', 'System-On-Chip Design', 'dchen'], 'ECE-549': ['ECE-549', 'Lazebnik, Svetlana', '2018-sp', 'Computer Vision', ''], 'ECE-544': ['ECE-544', 'Schwing, Alexander G', '2018-fa', 'Pattern Recognition', 'aschwing'], 'ECE-546': ['ECE-546', 'Schutt-Aine, Jose E', '2018-sp', 'Advanced Signal Integrity', 'jesa'], 'ECE-547': ['ECE-547', 'Schwing, Alexander G', '2017-sp', 'Topics in Image Processing', 'aschwing'], 'ECE-541': ['ECE-541', 'Noureddine, Mohammad', '2018-fa', 'Computer Systems Analysis', ''], 'ECE-543': ['ECE-543', 'Raginsky, Maxim', '2018-sp', 'Statistical Learning Theory', 'maxim'], 'ECE-311': ['ECE-311', 'Bresler, Yoram', '2018-fa', 'Digital Signal Processing Lab', 'ybresler'], 'ECE-310': ['ECE-310', 'Shomorony, Ilan', '2018-fa', 'Digital Signal Processing', 'ilans'], 'ECE-313': ['ECE-313', 'Veeravalli, Venugopal V', '2018-fa', 'Probability with Engrg Applic', 'vvv'], 'ECE-314': ['ECE-314', 'Hajek, Bruce', '2018-fa', 'Probability in Engineering Lab', 'b-hajek'], 'ECE-317': ['ECE-317', 'H ...
